# %% [markdown]
# # AI-Local 🧠 — Chat tiếng Việt trên Google Colab
#
# Chạy ô bên dưới (bấm nút ▶). Sau khoảng 1 phút sẽ hiện một **link công khai** dạng `https://xxxxx.gradio.live`.
#
# Bấm vào link đó là **chat ngay trên điện thoại** — không cần cài gì cả.

# %%
# !git clone -b claude/local-language-model-3g7ije https://github.com/luibobo932/AI-local
# %cd AI-local
# !pip install -q torch numpy gradio
# !python app.py
